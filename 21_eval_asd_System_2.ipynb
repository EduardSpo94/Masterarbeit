# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 1. Remove conflicting packages to ensure a clean state
# !pip uninstall -y tensorflow keras tf-keras

# 2. Install TensorFlow and necessary audio processing dependencies
# We use 'tf_keras' as the modern interface for TensorFlow 2.16+
# !pip install tensorflow tf_keras librosa==0.9.1 soundfile tqdm

print("✅ Environment successfully cleaned and dependencies installed.")
print("⚠️ IMPORTANT: Please restart the session now via 'Runtime' -> 'Restart session' to apply changes.")
# Out:
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# Found existing installation: keras 3.13.2
# Uninstalling keras-3.13.2:
#   Successfully uninstalled keras-3.13.2
# Found existing installation: tf_keras 2.19.0
# Uninstalling tf_keras-2.19.0:
#   Successfully uninstalled tf_keras-2.19.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 23.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 87.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 142.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 100.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 127.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
# ...

# %%
# Change to the main project directory
# %cd /content/drive/MyDrive/MasterProject/

# Change to the specific System2 folder
# %cd dcase2022_task2_baseline_mobile_net_v2-main_System2
# Out:
# /content/drive/MyDrive/MasterProject
# /content/drive/MyDrive/MasterProject/dcase2022_task2_baseline_mobile_net_v2-main_System2

# %%
# Start training with the threshold of 0.5 as defined in your YAML configuration
# !python 00_train.py -d
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776180356.068610   24249 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776180356.137151   24249 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...

# %%
# ==============================================================================
# EXECUTION: STARTING EVALUATION
# ==============================================================================
# !python 01_test.py -d
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1776267128.687431   89083 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1776267128.760009   89083 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# ...
