# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# 1. Remove conflicting packages to ensure a clean state
# !pip uninstall -y tensorflow keras tf-keras

# 2. Install TensorFlow and necessary audio processing dependencies
# We use 'tf_keras' as the modern interface for TensorFlow 2.16+
# !pip install tensorflow tf_keras librosa==0.9.1 soundfile tqdm

print("✅ Environment successfully cleaned and dependencies installed.")
# Out:
# Found existing installation: tensorflow 2.19.0
# Uninstalling tensorflow-2.19.0:
#   Successfully uninstalled tensorflow-2.19.0
# Found existing installation: keras 3.13.2
# Uninstalling keras-3.13.2:
#   Successfully uninstalled keras-3.13.2
# Found existing installation: tf_keras 2.19.0
# Uninstalling tf_keras-2.19.0:
#   Successfully uninstalled tf_keras-2.19.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.1/213.1 kB 20.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.6/572.6 MB 2.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 95.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 155.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 105.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 324.3/324.3 kB 35.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 132.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
# ...

# %%
import os
from google.colab import drive

# 1. Mount Google Drive
if not os.path.exists('/content/drive'):
    print("🔌 Mounting Google Drive...")
    drive.mount('/content/drive')

# 2. Set working directory
# Using the direct path to your baseline project folder
BASE_DIR = '/content/drive/MyDrive/MasterProject/baseline_code'
os.chdir(BASE_DIR)
print(f"📂 Switched to directory: {os.getcwd()}")

# 3. Fix imports & environment
print("🔧 Preparing environment...")
# Replace legacy imports if necessary
# !sed -i 's/import tf_keras_model/import keras_model/g' *.py 2>/dev/null
# !sed -i 's/from tf_keras_model/from keras_model/g' *.py 2>/dev/null
# !sed -i 's/import tf_common/import common/g' *.py 2>/dev/null

# Set environment variable for legacy Keras support
os.environ["TF_USE_LEGACY_KERAS"] = "1"

# 4. Start training
print("\n🚀 STARTING TRAINING...")
# Execute the training script
# !python 00_train.py -d
# Out:
# 🔍 Scanne dein Drive nach '00_train.py' (das kann kurz dauern)...
#
# ✅ TREFFER! Code gefunden in: /content/drive/MyDrive/MasterProject/dcase2022_task2_baseline_ae-main
# 📂 Bin in den Ordner gewechselt.
# 🔧 Repariere Imports...
#
# 🚀 STARTE TRAINING...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1774988683.458671   39510 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEBUG:2026-03-31 20:24:46,613:jax._src.path:41: etils.epath found. Using etils.epath for file I/O.
#
# 🌱 Setting Random Seed to 523423...
# 2026-03-31 20:24:47,789 - INFO - load_directory <- development
#
# ...
# [1/1] /content/drive/MyDrive/MasterProject/data/raw/mimii_dg/dev_bearing/bearing
# ============== DATASET_GENERATOR ==============
# ...

# %%
import os

# 1. Ensure we are in the correct directory
project_path = "/content/drive/MyDrive/MasterProject/dcase2022_task2_baseline_ae-main"
os.chdir(project_path)
print(f"📂 Switched to directory: {os.getcwd()}")

# 2. Start test run
# -d stands for the development model
print("🧪 Starting evaluation on test data...")
# !python 01_test.py -d
# Out:
# 🧪 Starte Evaluation auf den Test-Daten...
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775588142.773136    2530 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# DEBUG:2026-04-07 18:55:47,484:jax._src.path:41: etils.epath found. Using etils.epath for file I/O.
# 2026-04-07 18:55:49,935 - INFO - load_directory <- development
#
# ...
# [1/1] /content/drive/MyDrive/MasterProject/data/raw/mimii_dg/dev_bearing/bearing
# ============== MODEL LOAD ==============
# W0000 00:00:1775588157.672558    2530 gpu_bfc_allocator.cc:47] Overriding orig_value setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was false.
# ...
